# %%
from __future__ import division, print_function
import csv, heapq, json, os, sys
from os.path import join
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import caffe
import experimenter.utilities
from experimenter.utilities import ExperimentResult, get_solver, read_snapshot_records
from experimenter.utilities import num_lines, get_best_record, print_json
from experimenter.utilities import test_net_with_snapshot, SnapshotRecord
from experimenter.finetune import folder2datasetsize, folder2experimentname
from experimenter.results import print_results, plot_prop, plot_test, plot_val, scatter_test, group2dir
# %load_ext autoreload
# %autoreload 2

# %%
from experiment import generate

# %%
print_results(group2dir(''))
# Out:
# /home/bchu/CS280MiniPlaces/runs/alexnet-stack-2/snapshots.csv
# ['iteration', 'val_accuracy', 'val_loss', 'train_loss', 'train_accuracy', 'deleted']
# ['6900', '0.6340000033378601', '2.6457206666469575', '2.4940061569213867', '0.67578125', '0']
# ['7200', '0.63119999915361402', '2.6402186691761016', '2.7208411693573', '0.62109375', '0']
#
# /home/bchu/CS280MiniPlaces/runs/scene-stack/snapshots.csv
# ['iteration', 'val_accuracy', 'val_loss', 'train_loss', 'train_accuracy', 'deleted']
# ['20400', '0.6716000035405159', '2.518370884656906', '1.9929330348968506', '0.7578125', '0']
# ['26400', '0.66920000016689296', '2.5212058544158937', '2.2673559188842773', '0.703125', '0']
#
# /home/bchu/CS280MiniPlaces/runs/alexnet-linear/snapshots.csv
# ['iteration', 'val_accuracy', 'val_loss', 'train_loss', 'train_accuracy', 'deleted']
# ['20100', '0.6826000019907952', '2.4633588075637816', '2.149003028869629', '0.71484375', '0']
# ['20400', '0.68140000253915789', '2.4647832989692686', '2.005131959915161', '0.78125', '1']
#
# /home/bchu/CS280MiniPlaces/runs/alexnet-batchnorm/snapshots.csv
# ['iteration', 'val_accuracy', 'val_loss', 'train_loss', 'train_accuracy', 'deleted']
# ['18000', '0.6707000017166138', '2.529729849100113', '1.9863507747650146', '0.77734375', '0']
# ['26400', '0.66820000261068346', '2.5319167494773867', '2.231619119644165', '0.71484375', '1']
#
# /home/bchu/CS280MiniPlaces/runs/alexnet/snapshots.csv
# ['iteration', 'val_accuracy', 'val_loss', 'train_loss', 'train_accuracy', 'deleted']
# ['28800', '0.616499999165535', '2.6860520422458647', '2.37730073928833', '0.67578125', '0']
# ['36300', '0.61590000092983244', '2.6859553396701812', '2.576441526412964', '0.65625', '0']
#
# /home/bchu/CS280MiniPlaces/runs/mini-alexnet/snapshots.csv
# ['iteration', 'val_accuracy', 'val_loss', 'train_loss', 'train_accuracy', 'deleted']
# ['30900', '0.6410000041127205', '2.618528825044632', '2.5045368671417236', '0.65625', '0']
# ['33300', '0.64070000499486923', '2.618678170442581', '2.606001138687134', '0.65234375', '0']

# %%
print_results(group2dir('experiment1'), query='train10-')

# %%
print_results(group2dir('experiment1'), query='train50-')

# %%
print_results(group2dir('experiment1'), query='train70-')

# %%
print_results(group2dir('experiment3'))

# %%
for e in generate(''):
    save_path = 'plots/' + e.dataset.name + e.name
    save_path=None
    plot_prop(e.folder, ['train_loss', 'train_accuracy', 'val_accuracy'], ylims=[None, None, None], save=save_path)

# %%
for e in generate('experiment1'):
    if 'train10-' not in e.folder:
        continue
    save_path = 'plots/' + e.dataset.name + e.name
    save_path=None
    plot_prop(e.folder, ['train_loss', 'val_loss', 'val_accuracy'], ylims=[None, None, None], save=save_path)

# %%
for e in generate('experiment1'):
    if 'train50-' not in e.folder:
        continue
    save_path = 'plots/' + e.dataset.name + e.name
    save_path=None
    plot_prop(e.folder, ['train_loss', 'val_loss', 'val_accuracy'], ylims=[None, None, None], save=save_path)

# %%
for e in generate('experiment1'):
    if 'train70-' not in e.folder:
        continue
    save_path = 'plots/' + e.dataset.name + e.name
    save_path=None
    plot_prop(e.folder, ['train_loss', 'val_loss', 'val_accuracy'], ylims=[None, None, None], save=save_path)

# %%
for e in generate('experiment3'):
#     if 'train70-' not in e.folder:
#         continue
    save_path = 'plots/' + e.dataset.name + e.name
    save_path=None
    plot_prop(e.folder, ['train_loss', 'val_loss', 'val_accuracy'], ylims=[None, None, [0, 0.8]], save=save_path)

# %%
plot_val(generate('experiment1'), ylim=[0.35, 0.54])

# %%
plot_test(['experiment1_results.json', 'baseline_results.json'], ylim=[0, 0.54])
scatter_test('experiment1_results.json', ylim=[0, 0.7], x='linear')
scatter_test('baseline_results.json', ylim=[0, 0.7], x='linear')

# %%
from imagenetdelta_experiment import generate as delta_generate
print_results(group2dir('', configpy='imagenetdelta_experiment.py'))
for e in delta_generate():
    save_path = 'plots/' + e.dataset.name + e.name
    save_path=None
    plot_prop(e.folder, ['train_loss', 'val_loss', 'val_accuracy'], ylims=[None, None, None], save=save_path)
scatter_test('imagenetdelta_experiment_results.json', ylim=[0.08, 1], x='size')
